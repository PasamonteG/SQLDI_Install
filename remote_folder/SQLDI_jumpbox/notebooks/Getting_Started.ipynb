# %% [markdown]
# # Notebook to Test Db2 Access

# %% [markdown]
# ![TestImage](img/GS01.JPG)

# %%
# pip install ipython-sql==0.4.1 ibm_db sqlalchemy==1.4.47 ibm_db_sa ibm_db

# %%
import sys,os,os.path
#os.environ['IBM_DB_HOME']='C:\Program Files\IBM\SQLLIB'
path_1 = os.path.join('C:\\','Program Files','IBM','IBM DATA SERVER DRIVER','bin')
os.add_dll_directory(path_1)
# Out:
# <AddedDllDirectory('C:\\Program Files\\IBM\\IBM DATA SERVER DRIVER\\bin')>

# %%
import ibm_db
import ibm_db_sa 
import sqlalchemy

# %%
# %load_ext sql

# %%
# %sql ibm_db_sa://tsodcgm:Montp2ll1erSystem@10.3.58.61:448/RDBNDW00

# %%
# %sql select * from zdw01.penguins
# Out:
#  * ibm_db_sa://tsodcgm:***@10.3.58.61:448/RDBNDW00
# Done.
# [(1, 'Adelie', 'Torgersen', Decimal('39.1'), Decimal('18.7'), 181, 3750, 'MALE'),
#  (2, 'Adelie', 'Torgersen', Decimal('39.5'), Decimal('17.4'), 186, 3800, 'FEMALE'),
#  (3, 'Adelie', 'Torgersen', Decimal('40.3'), Decimal('18.0'), 195, 3250, 'FEMALE'),
#  (4, 'Adelie', 'Torgersen', None, None, None, None, None),
#  (5, 'Adelie', 'Torgersen', Decimal('36.7'), Decimal('19.3'), 193, 3450, 'FEMALE'),
#  (6, 'Adelie', 'Torgersen', Decimal('39.3'), Decimal('20.6'), 190, 3650, 'MALE'),
#  (7, 'Adelie', 'Torgersen', Decimal('38.9'), Decimal('17.8'), 181, 3625, 'FEMALE'),
#  (8, 'Adelie', 'Torgersen', Decimal('39.2'), Decimal('19.6'), 195, 4675, 'MALE'),
#  (9, 'Adelie', 'Torgersen', Decimal('34.1'), Decimal('18.1'), 193, 3475, None),
#  (10, 'Adelie', 'Torgersen', Decimal('42.0'), Decimal('20.2'), 190, 4250, None),
#  (11, 'Adelie', 'Torgersen', Decimal('37.8'), Decimal('17.1'), 186, 3300, None),
# ...

# %%
# %sql select * from credit.txns where is_fraud = 'Yes' fetch first 10 rows only

# %%
# %sql select tbcreator, tbname, colno, name from sysibm.syscolumns where tbcreator = 'CREDIT' order by tbname, colno asc
